# %%
from ortools.sat.python import cp_model
from time import time
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import ortools

#import local module
from utils import get_holiday, get_morn_con_day

# %%
# Select month and year to schedule
month = 3
year = 2023
num_days = (datetime(year, month+1, 1) - datetime(year, month, 1)).days # Get number of days in month
date_list = [datetime(year, month, day) for day in range(1, num_days+1)] # Get list of date in month

#Get holiday list
holiday = get_holiday(year, month)

print(holiday)
# Out:
# [False, False, False, True, True, True, False, False, False, False, True, True, False, False, False, False, False, True, True, False, False, False, False, False, True, True, False, False, False, False, False]

# %%
# ============================= Input ============================= #

# List of staffs
staff_names = ["อ.บริบูรณ์","อ.ณัฐฐิกานต์","อ.ปริญญา","อ.ภาวิตา","อ.ธีรพล","อ.บวร","อ.ชานนท์","อ.บุญฤทธิ์","อ.กอสิน","อ.พิมพ์พรรณ","อ.กรองกาญจน์"]
num_staffs = len(staff_names)

# Select month and year to schedule & 
month = 3
year = 2023
num_days = (datetime(year, month+1, 1) - datetime(year, month, 1)).days
date_list = [datetime(year, month, day) for day in range(1, num_days+1)]

#Get holiday list
holiday = get_holiday(year, month)

#Get morn con day list
morn_con_day = get_morn_con_day(year, month)
no_morn_con_day = [i for i in range(num_days) if i not in morn_con_day]

# List of shifts
shift_names = ['off', 'service1', 'service2', 'service1+', 'service2+', 'Observe', 'Morn Con', 'EMS',  'AMD']
num_shifts = len(shift_names) # 9 shifts per day


# ============================= Create model ============================= #

model = cp_model.CpModel()

# Create shift variables.
# shifts[(s, d, w)]: staff 's' works shift 'w' on day 'd'.
shifts = {}
for s in range(num_staffs):
    for d in range(num_days):
        for w in range(num_shifts):
            shifts[(s, d, w)] = model.NewBoolVar('shift_s%id%iw%i' % (s, d, w))

# ============================= Required Constraints ============================= #

# For (EMS & AMD) Each shift is assigned to exactly one staff in that day, include holiday
for d in range(num_days):
    for w in [7, 8]:
        model.AddExactlyOne([shifts[(s, d, w)] for s in range(num_staffs)])

# For (service1 & service2 & service1+ & service2+ & observe) Each shift is assigned to exactly one staff in that day, exclude holiday
for d in range(num_days):
    if holiday[d] == False:
        for w in [1, 2, 3, 4, 5]:
            model.AddExactlyOne([shifts[(s, d, w)] for s in range(num_staffs)])

# For morning conference Each shift is assigned to exactly one staff in that day, exclude holiday and no morn con day
for d in range(num_days):
    if morn_con_day[d] == True:
            model.AddExactlyOne([shifts[(s, d, 6)] for s in range(num_staffs)])

# Each staff works at most one shift per day.
for s in range(num_staffs):
    for d in range(num_days):
        model.AddExactlyOne([shifts[(s, d, w)] for w in range(num_shifts)])

# ============================= Optional Constraints ============================= #







# ============================= Solve ============================= #


# Solution printer.
class ShiftSolutionPrinter(cp_model.CpSolverSolutionCallback):

    def __init__(self, shifts, num_staffs, num_days, num_shifts):
        cp_model.CpSolverSolutionCallback.__init__(self)
        self._shifts = shifts
        self._num_staffs = num_staffs
        self._num_days = num_days
        self._num_shifts = num_shifts
        self._solution_count = 0

    def OnSolutionCallback(self):
        self._solution_count += 1

        #Workload per staff
        workload = np.zeros(self._num_staffs)
        for s in range(self._num_staffs):
            for d in range(self._num_days):
                for w in range(1, self._num_shifts): # exclude 'off'
                    workload[s] += self.Value(self._shifts[(s, d, w)])
        print(workload)


        ls=[]
        for d in range(self._num_days):
            ls_day=[]
            for w in range(self._num_shifts):
                ls_shift=[]
                for s in range(self._num_staffs):
                    if self.Value(self._shifts[(s, d, w)]):
                        ls_shift.append(staff_names[s])
                ls_day.append(ls_shift)
            ls.append(ls_day)
        
        df = pd.DataFrame(ls, index=date_list, columns=shift_names)
        print(df)

        df.to_csv('schedule.csv', index=True, header=True)

    def SolutionCount(self):
        return self._solution_count


# Solve model.
solver = cp_model.CpSolver()
solver.parameters.max_time_in_seconds = 10.0
solution_printer = ShiftSolutionPrinter(shifts, num_staffs, num_days, num_shifts)
status = solver.Solve(model, solution_printer)
# status = solver.Solve(model)
print(solver.ResponseStats())
# Out:
# [27. 24. 24. 24. 19. 21. 19. 13.  5.  7.  6.]
#                                                           off        service1  \
# 2023-03-01   [อ.บุญฤทธิ์, อ.กอสิน, อ.พิมพ์พรรณ, อ.กรองกาญจน์]      [อ.ภาวิตา]
# 2023-03-02               [อ.กอสิน, อ.พิมพ์พรรณ, อ.กรองกาญจน์]  [อ.ณัฐฐิกานต์]
# 2023-03-03            [อ.บุญฤทธิ์, อ.พิมพ์พรรณ, อ.กรองกาญจน์]      [อ.ปริญญา]
# 2023-03-04  [อ.ปริญญา, อ.ภาวิตา, อ.ธีรพล, อ.บวร, อ.ชานนท์,...              []
# 2023-03-05  [อ.ปริญญา, อ.ภาวิตา, อ.ธีรพล, อ.บวร, อ.ชานนท์,...              []
# 2023-03-06  [อ.ณัฐฐิกานต์, อ.ภาวิตา, อ.ธีรพล, อ.บวร, อ.ชาน...              []
# 2023-03-07                [อ.บุญฤทธิ์, อ.กอสิน, อ.กรองกาญจน์]  [อ.ณัฐฐิกานต์]
# 2023-03-08   [อ.บุญฤทธิ์, อ.กอสิน, อ.พิมพ์พรรณ, อ.กรองกาญจน์]    [อ.บริบูรณ์]
# 2023-03-09            [อ.บุญฤทธิ์, อ.พิมพ์พรรณ, อ.กรองกาญจน์]    [อ.บริบูรณ์]
# 2023-03-10                [อ.บุญฤทธิ์, อ.กอสิน, อ.กรองกาญจน์]      [อ.ปริญญา]
# 2023-03-11  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ปริญญา, อ.ธีรพล, ...              []
# 2023-03-12  [อ.บริบูรณ์, อ.ปริญญา, อ.ภาวิตา, อ.ธีรพล, อ.บว...              []
# 2023-03-13               [อ.กอสิน, อ.พิมพ์พรรณ, อ.กรองกาญจน์]      [อ.ภาวิตา]
# 2023-03-14                [อ.บริบูรณ์, อ.ชานนท์, อ.พิมพ์พรรณ]    [อ.บุญฤทธิ์]
# 2023-03-15      [อ.ธีรพล, อ.กอสิน, อ.พิมพ์พรรณ, อ.กรองกาญจน์]    [อ.บริบูรณ์]
# 2023-03-16                [อ.บุญฤทธิ์, อ.กอสิน, อ.กรองกาญจน์]  [อ.ณัฐฐิกานต์]
# 2023-03-17               [อ.กอสิน, อ.พิมพ์พรรณ, อ.กรองกาญจน์]  [อ.ณัฐฐิกานต์]
# 2023-03-18  [อ.ณัฐฐิกานต์, อ.ปริญญา, อ.ภาวิตา, อ.ธีรพล, อ....              []
# 2023-03-19  [อ.ณัฐฐิกานต์, อ.ภาวิตา, อ.ธีรพล, อ.บวร, อ.ชาน...              []
# 2023-03-20                    [อ.ธีรพล, อ.กอสิน, อ.พิมพ์พรรณ]    [อ.บริบูรณ์]
# 2023-03-21                  [อ.ชานนท์, อ.กอสิน, อ.กรองกาญจน์]    [อ.บริบูรณ์]
# 2023-03-22     [อ.ชานนท์, อ.กอสิน, อ.พิมพ์พรรณ, อ.กรองกาญจน์]    [อ.บริบูรณ์]
# 2023-03-23               [อ.กอสิน, อ.พิมพ์พรรณ, อ.กรองกาญจน์]    [อ.บริบูรณ์]
# 2023-03-24              [อ.ณัฐฐิกานต์, อ.กอสิน, อ.กรองกาญจน์]    [อ.บริบูรณ์]
# 2023-03-25  [อ.ณัฐฐิกานต์, อ.ปริญญา, อ.ธีรพล, อ.บวร, อ.ชาน...              []
# 2023-03-26  [อ.ณัฐฐิกานต์, อ.ปริญญา, อ.ธีรพล, อ.บวร, อ.ชาน...              []
# 2023-03-27              [อ.ชานนท์, อ.พิมพ์พรรณ, อ.กรองกาญจน์]    [อ.บริบูรณ์]
# 2023-03-28                   [อ.บริบูรณ์, อ.ภาวิตา, อ.ชานนท์]  [อ.ณัฐฐิกานต์]
# 2023-03-29            [อ.บวร, อ.ชานนท์, อ.กอสิน, อ.พิมพ์พรรณ]    [อ.บริบูรณ์]
# 2023-03-30                 [อ.บุญฤทธิ์, อ.กอสิน, อ.พิมพ์พรรณ]    [อ.บริบูรณ์]
# 2023-03-31                     [อ.ธีรพล, อ.บุญฤทธิ์, อ.กอสิน]      [อ.ปริญญา]
#
#                   service2       service1+       service2+         Observe  \
# 2023-03-01         [อ.บวร]    [อ.บริบูรณ์]  [อ.ณัฐฐิกานต์]       [อ.ธีรพล]
# 2023-03-02    [อ.บุญฤทธิ์]    [อ.บริบูรณ์]      [อ.ภาวิตา]       [อ.ธีรพล]
# 2023-03-03  [อ.ณัฐฐิกานต์]    [อ.บริบูรณ์]      [อ.ภาวิตา]       [อ.ธีรพล]
# 2023-03-04              []              []              []              []
# 2023-03-05              []              []              []              []
# 2023-03-06              []              []              []              []
# 2023-03-07      [อ.ภาวิตา]    [อ.บริบูรณ์]      [อ.ปริญญา]       [อ.ธีรพล]
# 2023-03-08  [อ.ณัฐฐิกานต์]      [อ.ปริญญา]         [อ.บวร]      [อ.ชานนท์]
# 2023-03-09  [อ.ณัฐฐิกานต์]       [อ.ธีรพล]      [อ.ปริญญา]      [อ.ภาวิตา]
# 2023-03-10      [อ.ภาวิตา]  [อ.ณัฐฐิกานต์]       [อ.ธีรพล]    [อ.บริบูรณ์]
# 2023-03-11              []              []              []              []
# 2023-03-12              []              []              []              []
# 2023-03-13      [อ.ปริญญา]      [อ.ชานนท์]    [อ.บริบูรณ์]  [อ.ณัฐฐิกานต์]
# 2023-03-14       [อ.กอสิน]      [อ.ปริญญา]       [อ.ธีรพล]      [อ.ภาวิตา]
# 2023-03-15  [อ.ณัฐฐิกานต์]      [อ.ปริญญา]      [อ.ภาวิตา]         [อ.บวร]
# 2023-03-16    [อ.บริบูรณ์]      [อ.ปริญญา]       [อ.ธีรพล]      [อ.ชานนท์]
# 2023-03-17      [อ.ภาวิตา]       [อ.ธีรพล]         [อ.บวร]    [อ.บริบูรณ์]
# 2023-03-18              []              []              []              []
# 2023-03-19              []              []              []              []
# 2023-03-20  [อ.ณัฐฐิกานต์]      [อ.ปริญญา]         [อ.บวร]      [อ.ภาวิตา]
# 2023-03-21  [อ.ณัฐฐิกานต์]      [อ.ปริญญา]      [อ.ภาวิตา]         [อ.บวร]
# 2023-03-22  [อ.ณัฐฐิกานต์]      [อ.ปริญญา]       [อ.ธีรพล]         [อ.บวร]
# 2023-03-23         [อ.บวร]  [อ.ณัฐฐิกานต์]      [อ.ชานนท์]      [อ.ปริญญา]
# 2023-03-24      [อ.ปริญญา]      [อ.ภาวิตา]      [อ.ชานนท์]       [อ.ธีรพล]
# 2023-03-25              []              []              []              []
# 2023-03-26              []              []              []              []
# 2023-03-27  [อ.ณัฐฐิกานต์]      [อ.ปริญญา]       [อ.ธีรพล]    [อ.บุญฤทธิ์]
# 2023-03-28      [อ.ปริญญา]         [อ.บวร]       [อ.ธีรพล]    [อ.บุญฤทธิ์]
# 2023-03-29      [อ.ปริญญา]  [อ.ณัฐฐิกานต์]      [อ.ภาวิตา]    [อ.บุญฤทธิ์]
# 2023-03-30      [อ.ภาวิตา]  [อ.ณัฐฐิกานต์]         [อ.บวร]      [อ.ปริญญา]
# 2023-03-31  [อ.ณัฐฐิกานต์]    [อ.บริบูรณ์]      [อ.ภาวิตา]         [อ.บวร]
#
#                   Morn Con            EMS             AMD
# 2023-03-01              []     [อ.ปริญญา]      [อ.ชานนท์]
# 2023-03-02      [อ.ปริญญา]        [อ.บวร]      [อ.ชานนท์]
# 2023-03-03         [อ.บวร]     [อ.ชานนท์]       [อ.กอสิน]
# 2023-03-04              []   [อ.บริบูรณ์]  [อ.ณัฐฐิกานต์]
# 2023-03-05              []   [อ.บริบูรณ์]  [อ.ณัฐฐิกานต์]
# 2023-03-06              []   [อ.บริบูรณ์]      [อ.ปริญญา]
# 2023-03-07   [อ.พิมพ์พรรณ]        [อ.บวร]      [อ.ชานนท์]
# 2023-03-08              []     [อ.ภาวิตา]       [อ.ธีรพล]
# 2023-03-09         [อ.บวร]     [อ.ชานนท์]       [อ.กอสิน]
# 2023-03-10         [อ.บวร]  [อ.พิมพ์พรรณ]      [อ.ชานนท์]
# 2023-03-11              []     [อ.ชานนท์]      [อ.ภาวิตา]
# 2023-03-12              []     [อ.ชานนท์]  [อ.ณัฐฐิกานต์]
# 2023-03-13         [อ.บวร]      [อ.ธีรพล]    [อ.บุญฤทธิ์]
# 2023-03-14  [อ.ณัฐฐิกานต์]        [อ.บวร]  [อ.กรองกาญจน์]
# 2023-03-15              []     [อ.ชานนท์]    [อ.บุญฤทธิ์]
# 2023-03-16         [อ.บวร]  [อ.พิมพ์พรรณ]      [อ.ภาวิตา]
# 2023-03-17      [อ.ชานนท์]     [อ.ปริญญา]    [อ.บุญฤทธิ์]
# 2023-03-18              []     [อ.ชานนท์]    [อ.บริบูรณ์]
# 2023-03-19              []   [อ.บริบูรณ์]      [อ.ปริญญา]
# 2023-03-20    [อ.บุญฤทธิ์]     [อ.ชานนท์]  [อ.กรองกาญจน์]
# 2023-03-21    [อ.บุญฤทธิ์]  [อ.พิมพ์พรรณ]       [อ.ธีรพล]
# 2023-03-22              []   [อ.บุญฤทธิ์]      [อ.ภาวิตา]
# 2023-03-23       [อ.ธีรพล]     [อ.ภาวิตา]    [อ.บุญฤทธิ์]
# 2023-03-24   [อ.พิมพ์พรรณ]        [อ.บวร]    [อ.บุญฤทธิ์]
# 2023-03-25              []     [อ.ภาวิตา]    [อ.บริบูรณ์]
# 2023-03-26              []     [อ.ภาวิตา]    [อ.บริบูรณ์]
# 2023-03-27         [อ.บวร]     [อ.ภาวิตา]       [อ.กอสิน]
# 2023-03-28       [อ.กอสิน]  [อ.พิมพ์พรรณ]  [อ.กรองกาญจน์]
# 2023-03-29              []      [อ.ธีรพล]  [อ.กรองกาญจน์]
# 2023-03-30       [อ.ธีรพล]     [อ.ชานนท์]  [อ.กรองกาญจน์]
# 2023-03-31      [อ.ชานนท์]  [อ.พิมพ์พรรณ]  [อ.กรองกาญจน์]
# [19. 19. 25. 20. 17. 11. 13. 18. 15. 14. 18.]
#                                                           off        service1  \
# 2023-03-01       [อ.ชานนท์, อ.บุญฤทธิ์, อ.กอสิน, อ.พิมพ์พรรณ]         [อ.บวร]
# 2023-03-02                    [อ.บวร, อ.ชานนท์, อ.กรองกาญจน์]    [อ.บริบูรณ์]
# 2023-03-03                       [อ.บวร, อ.บุญฤทธิ์, อ.กอสิน]      [อ.ปริญญา]
# 2023-03-04  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ปริญญา, อ.ภาวิตา,...              []
# 2023-03-05  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ภาวิตา, อ.ธีรพล, ...              []
# 2023-03-06  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ภาวิตา, อ.ธีรพล, ...              []
# 2023-03-07                [อ.บริบูรณ์, อ.ปริญญา, อ.พิมพ์พรรณ]  [อ.กรองกาญจน์]
# 2023-03-08      [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ธีรพล, อ.ชานนท์]       [อ.กอสิน]
# 2023-03-09                 [อ.บุญฤทธิ์, อ.กอสิน, อ.พิมพ์พรรณ]      [อ.ชานนท์]
# 2023-03-10            [อ.บริบูรณ์, อ.พิมพ์พรรณ, อ.กรองกาญจน์]      [อ.ภาวิตา]
# 2023-03-11  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ปริญญา, อ.ภาวิตา,...              []
# 2023-03-12  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ภาวิตา, อ.ธีรพล, ...              []
# 2023-03-13                       [อ.บวร, อ.บุญฤทธิ์, อ.กอสิน]       [อ.ธีรพล]
# 2023-03-14                       [อ.บวร, อ.บุญฤทธิ์, อ.กอสิน]      [อ.ปริญญา]
# 2023-03-15            [อ.ภาวิตา, อ.บวร, อ.กอสิน, อ.พิมพ์พรรณ]  [อ.ณัฐฐิกานต์]
# 2023-03-16                 [อ.บุญฤทธิ์, อ.กอสิน, อ.พิมพ์พรรณ]      [อ.ชานนท์]
# 2023-03-17                         [อ.ธีรพล, อ.บวร, อ.ชานนท์]      [อ.ปริญญา]
# 2023-03-18  [อ.ณัฐฐิกานต์, อ.ปริญญา, อ.ภาวิตา, อ.ธีรพล, อ....              []
# 2023-03-19  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ภาวิตา, อ.ธีรพล, ...              []
# 2023-03-20                    [อ.บวร, อ.ชานนท์, อ.กรองกาญจน์]   [อ.พิมพ์พรรณ]
# 2023-03-21                         [อ.ธีรพล, อ.บวร, อ.ชานนท์]      [อ.ปริญญา]
# 2023-03-22             [อ.บวร, อ.ชานนท์, อ.บุญฤทธิ์, อ.กอสิน]      [อ.ภาวิตา]
# 2023-03-23                        [อ.ภาวิตา, อ.บวร, อ.ชานนท์]      [อ.ปริญญา]
# 2023-03-24                       [อ.ธีรพล, อ.ชานนท์, อ.กอสิน]    [อ.บุญฤทธิ์]
# 2023-03-25  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ภาวิตา, อ.ธีรพล, ...              []
# 2023-03-26  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ปริญญา, อ.ภาวิตา,...              []
# 2023-03-27                    [อ.ธีรพล, อ.ชานนท์, อ.บุญฤทธิ์]      [อ.ภาวิตา]
# 2023-03-28                 [อ.ณัฐฐิกานต์, อ.บวร, อ.พิมพ์พรรณ]    [อ.บุญฤทธิ์]
# 2023-03-29  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ปริญญา, อ.กรองกาญ...   [อ.พิมพ์พรรณ]
# 2023-03-30                    [อ.ธีรพล, อ.กอสิน, อ.พิมพ์พรรณ]      [อ.ปริญญา]
# 2023-03-31                    [อ.ชานนท์, อ.บุญฤทธิ์, อ.กอสิน]         [อ.บวร]
#
#                   service2       service1+       service2+         Observe  \
# 2023-03-01       [อ.ธีรพล]      [อ.ปริญญา]    [อ.บริบูรณ์]  [อ.กรองกาญจน์]
# 2023-03-02  [อ.ณัฐฐิกานต์]   [อ.พิมพ์พรรณ]       [อ.ธีรพล]      [อ.ปริญญา]
# 2023-03-03  [อ.ณัฐฐิกานต์]       [อ.ธีรพล]   [อ.พิมพ์พรรณ]      [อ.ภาวิตา]
# 2023-03-04              []              []              []              []
# 2023-03-05              []              []              []              []
# 2023-03-06              []              []              []              []
# 2023-03-07       [อ.ธีรพล]    [อ.บุญฤทธิ์]       [อ.กอสิน]      [อ.ชานนท์]
# 2023-03-08      [อ.ภาวิตา]         [อ.บวร]      [อ.ปริญญา]    [อ.บุญฤทธิ์]
# 2023-03-09       [อ.ธีรพล]    [อ.บริบูรณ์]  [อ.ณัฐฐิกานต์]         [อ.บวร]
# 2023-03-10      [อ.ปริญญา]       [อ.ธีรพล]  [อ.ณัฐฐิกานต์]    [อ.บุญฤทธิ์]
# 2023-03-11              []              []              []              []
# 2023-03-12              []              []              []              []
# 2023-03-13   [อ.พิมพ์พรรณ]      [อ.ชานนท์]    [อ.บริบูรณ์]  [อ.กรองกาญจน์]
# 2023-03-14      [อ.ชานนท์]   [อ.พิมพ์พรรณ]       [อ.ธีรพล]      [อ.ภาวิตา]
# 2023-03-15      [อ.ปริญญา]       [อ.ธีรพล]    [อ.บริบูรณ์]  [อ.กรองกาญจน์]
# 2023-03-16      [อ.ภาวิตา]       [อ.ธีรพล]      [อ.ปริญญา]  [อ.ณัฐฐิกานต์]
# 2023-03-17      [อ.ภาวิตา]       [อ.กอสิน]  [อ.ณัฐฐิกานต์]   [อ.พิมพ์พรรณ]
# 2023-03-18              []              []              []              []
# 2023-03-19              []              []              []              []
# 2023-03-20       [อ.ธีรพล]    [อ.บริบูรณ์]  [อ.ณัฐฐิกานต์]    [อ.บุญฤทธิ์]
# 2023-03-21    [อ.บริบูรณ์]    [อ.บุญฤทธิ์]  [อ.กรองกาญจน์]      [อ.ภาวิตา]
# 2023-03-22       [อ.ธีรพล]  [อ.กรองกาญจน์]   [อ.พิมพ์พรรณ]      [อ.ปริญญา]
# 2023-03-23       [อ.ธีรพล]    [อ.บริบูรณ์]   [อ.พิมพ์พรรณ]    [อ.บุญฤทธิ์]
# 2023-03-24   [อ.พิมพ์พรรณ]      [อ.ปริญญา]    [อ.บริบูรณ์]  [อ.ณัฐฐิกานต์]
# 2023-03-25              []              []              []              []
# 2023-03-26              []              []              []              []
# 2023-03-27      [อ.ปริญญา]   [อ.พิมพ์พรรณ]  [อ.กรองกาญจน์]    [อ.บริบูรณ์]
# 2023-03-28      [อ.ชานนท์]       [อ.กอสิน]      [อ.ปริญญา]       [อ.ธีรพล]
# 2023-03-29         [อ.บวร]      [อ.ภาวิตา]      [อ.ชานนท์]       [อ.ธีรพล]
# 2023-03-30      [อ.ภาวิตา]         [อ.บวร]  [อ.ณัฐฐิกานต์]      [อ.ชานนท์]
# 2023-03-31   [อ.พิมพ์พรรณ]    [อ.บริบูรณ์]      [อ.ปริญญา]  [อ.ณัฐฐิกานต์]
#
#                   Morn Con             EMS             AMD
# 2023-03-01              []  [อ.ณัฐฐิกานต์]      [อ.ภาวิตา]
# 2023-03-02       [อ.กอสิน]      [อ.ภาวิตา]    [อ.บุญฤทธิ์]
# 2023-03-03  [อ.กรองกาญจน์]      [อ.ชานนท์]    [อ.บริบูรณ์]
# 2023-03-04              []      [อ.ชานนท์]       [อ.กอสิน]
# 2023-03-05              []      [อ.ปริญญา]      [อ.ชานนท์]
# 2023-03-06              []      [อ.ปริญญา]       [อ.กอสิน]
# 2023-03-07  [อ.ณัฐฐิกานต์]         [อ.บวร]      [อ.ภาวิตา]
# 2023-03-08              []   [อ.พิมพ์พรรณ]  [อ.กรองกาญจน์]
# 2023-03-09      [อ.ภาวิตา]      [อ.ปริญญา]  [อ.กรองกาญจน์]
# 2023-03-10       [อ.กอสิน]      [อ.ชานนท์]         [อ.บวร]
# 2023-03-11              []    [อ.บุญฤทธิ์]       [อ.ธีรพล]
# 2023-03-12              []    [อ.บุญฤทธิ์]      [อ.ปริญญา]
# 2023-03-13  [อ.ณัฐฐิกานต์]      [อ.ปริญญา]      [อ.ภาวิตา]
# 2023-03-14  [อ.กรองกาญจน์]    [อ.บริบูรณ์]  [อ.ณัฐฐิกานต์]
# 2023-03-15              []      [อ.ชานนท์]    [อ.บุญฤทธิ์]
# 2023-03-16    [อ.บริบูรณ์]         [อ.บวร]  [อ.กรองกาญจน์]
# 2023-03-17    [อ.บริบูรณ์]  [อ.กรองกาญจน์]    [อ.บุญฤทธิ์]
# 2023-03-18              []       [อ.กอสิน]    [อ.บริบูรณ์]
# 2023-03-19              []      [อ.ปริญญา]    [อ.บุญฤทธิ์]
# 2023-03-20       [อ.กอสิน]      [อ.ภาวิตา]      [อ.ปริญญา]
# 2023-03-21  [อ.ณัฐฐิกานต์]       [อ.กอสิน]   [อ.พิมพ์พรรณ]
# 2023-03-22              []    [อ.บริบูรณ์]  [อ.ณัฐฐิกานต์]
# 2023-03-23  [อ.กรองกาญจน์]  [อ.ณัฐฐิกานต์]       [อ.กอสิน]
# 2023-03-24  [อ.กรองกาญจน์]      [อ.ภาวิตา]         [อ.บวร]
# 2023-03-25              []    [อ.บุญฤทธิ์]      [อ.ปริญญา]
# 2023-03-26              []    [อ.บุญฤทธิ์]       [อ.กอสิน]
# 2023-03-27       [อ.กอสิน]         [อ.บวร]  [อ.ณัฐฐิกานต์]
# 2023-03-28      [อ.ภาวิตา]    [อ.บริบูรณ์]  [อ.กรองกาญจน์]
# 2023-03-29              []    [อ.บุญฤทธิ์]       [อ.กอสิน]
# 2023-03-30    [อ.บุญฤทธิ์]    [อ.บริบูรณ์]  [อ.กรองกาญจน์]
# 2023-03-31      [อ.ภาวิตา]       [อ.ธีรพล]  [อ.กรองกาญจน์]
# [19. 19. 25. 20. 17. 11. 13. 18. 15. 14. 18.]
#                                                           off        service1  \
# 2023-03-01       [อ.ชานนท์, อ.บุญฤทธิ์, อ.กอสิน, อ.พิมพ์พรรณ]         [อ.บวร]
# 2023-03-02                    [อ.บวร, อ.ชานนท์, อ.กรองกาญจน์]    [อ.บริบูรณ์]
# 2023-03-03                       [อ.บวร, อ.บุญฤทธิ์, อ.กอสิน]      [อ.ปริญญา]
# 2023-03-04  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ปริญญา, อ.ภาวิตา,...              []
# 2023-03-05  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ภาวิตา, อ.ธีรพล, ...              []
# 2023-03-06  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ภาวิตา, อ.ธีรพล, ...              []
# 2023-03-07                [อ.บริบูรณ์, อ.ปริญญา, อ.พิมพ์พรรณ]  [อ.กรองกาญจน์]
# 2023-03-08      [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ธีรพล, อ.ชานนท์]       [อ.กอสิน]
# 2023-03-09                 [อ.บุญฤทธิ์, อ.กอสิน, อ.พิมพ์พรรณ]      [อ.ชานนท์]
# 2023-03-10            [อ.บริบูรณ์, อ.พิมพ์พรรณ, อ.กรองกาญจน์]      [อ.ภาวิตา]
# 2023-03-11  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ปริญญา, อ.ภาวิตา,...              []
# 2023-03-12  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ภาวิตา, อ.ธีรพล, ...              []
# 2023-03-13                       [อ.บวร, อ.บุญฤทธิ์, อ.กอสิน]       [อ.ธีรพล]
# 2023-03-14                       [อ.บวร, อ.บุญฤทธิ์, อ.กอสิน]      [อ.ปริญญา]
# 2023-03-15            [อ.ภาวิตา, อ.บวร, อ.กอสิน, อ.พิมพ์พรรณ]  [อ.ณัฐฐิกานต์]
# 2023-03-16                 [อ.บุญฤทธิ์, อ.กอสิน, อ.พิมพ์พรรณ]      [อ.ชานนท์]
# 2023-03-17                         [อ.ธีรพล, อ.บวร, อ.ชานนท์]      [อ.ปริญญา]
# 2023-03-18  [อ.ณัฐฐิกานต์, อ.ปริญญา, อ.ภาวิตา, อ.ธีรพล, อ....              []
# 2023-03-19  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ภาวิตา, อ.ธีรพล, ...              []
# 2023-03-20                    [อ.บวร, อ.ชานนท์, อ.กรองกาญจน์]   [อ.พิมพ์พรรณ]
# 2023-03-21                         [อ.ธีรพล, อ.บวร, อ.ชานนท์]      [อ.ปริญญา]
# 2023-03-22             [อ.บวร, อ.ชานนท์, อ.บุญฤทธิ์, อ.กอสิน]      [อ.ภาวิตา]
# 2023-03-23                        [อ.ภาวิตา, อ.บวร, อ.ชานนท์]      [อ.ปริญญา]
# 2023-03-24                       [อ.ธีรพล, อ.ชานนท์, อ.กอสิน]    [อ.บุญฤทธิ์]
# 2023-03-25  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ภาวิตา, อ.ธีรพล, ...              []
# 2023-03-26  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ปริญญา, อ.ภาวิตา,...              []
# 2023-03-27                    [อ.ธีรพล, อ.ชานนท์, อ.บุญฤทธิ์]      [อ.ภาวิตา]
# 2023-03-28                 [อ.ณัฐฐิกานต์, อ.บวร, อ.พิมพ์พรรณ]    [อ.บุญฤทธิ์]
# 2023-03-29  [อ.บริบูรณ์, อ.ณัฐฐิกานต์, อ.ปริญญา, อ.กรองกาญ...   [อ.พิมพ์พรรณ]
# 2023-03-30                    [อ.ธีรพล, อ.กอสิน, อ.พิมพ์พรรณ]      [อ.ปริญญา]
# 2023-03-31                    [อ.ชานนท์, อ.บุญฤทธิ์, อ.กอสิน]         [อ.บวร]
#
#                   service2       service1+       service2+         Observe  \
# 2023-03-01       [อ.ธีรพล]      [อ.ปริญญา]    [อ.บริบูรณ์]  [อ.กรองกาญจน์]
# 2023-03-02  [อ.ณัฐฐิกานต์]   [อ.พิมพ์พรรณ]       [อ.ธีรพล]      [อ.ปริญญา]
# 2023-03-03  [อ.ณัฐฐิกานต์]       [อ.ธีรพล]   [อ.พิมพ์พรรณ]      [อ.ภาวิตา]
# 2023-03-04              []              []              []              []
# 2023-03-05              []              []              []              []
# 2023-03-06              []              []              []              []
# 2023-03-07       [อ.ธีรพล]    [อ.บุญฤทธิ์]       [อ.กอสิน]      [อ.ชานนท์]
# 2023-03-08      [อ.ภาวิตา]         [อ.บวร]      [อ.ปริญญา]    [อ.บุญฤทธิ์]
# 2023-03-09       [อ.ธีรพล]    [อ.บริบูรณ์]  [อ.ณัฐฐิกานต์]         [อ.บวร]
# 2023-03-10      [อ.ปริญญา]       [อ.ธีรพล]  [อ.ณัฐฐิกานต์]    [อ.บุญฤทธิ์]
# 2023-03-11              []              []              []              []
# 2023-03-12              []              []              []              []
# 2023-03-13   [อ.พิมพ์พรรณ]      [อ.ชานนท์]    [อ.บริบูรณ์]  [อ.กรองกาญจน์]
# 2023-03-14      [อ.ชานนท์]   [อ.พิมพ์พรรณ]       [อ.ธีรพล]      [อ.ภาวิตา]
# 2023-03-15      [อ.ปริญญา]       [อ.ธีรพล]    [อ.บริบูรณ์]  [อ.กรองกาญจน์]
# 2023-03-16      [อ.ภาวิตา]       [อ.ธีรพล]      [อ.ปริญญา]  [อ.ณัฐฐิกานต์]
# 2023-03-17      [อ.ภาวิตา]       [อ.กอสิน]  [อ.ณัฐฐิกานต์]   [อ.พิมพ์พรรณ]
# 2023-03-18              []              []              []              []
# 2023-03-19              []              []              []              []
# 2023-03-20       [อ.ธีรพล]    [อ.บริบูรณ์]  [อ.ณัฐฐิกานต์]    [อ.บุญฤทธิ์]
# 2023-03-21    [อ.บริบูรณ์]    [อ.บุญฤทธิ์]  [อ.กรองกาญจน์]      [อ.ภาวิตา]
# 2023-03-22       [อ.ธีรพล]  [อ.กรองกาญจน์]   [อ.พิมพ์พรรณ]      [อ.ปริญญา]
# 2023-03-23       [อ.ธีรพล]    [อ.บริบูรณ์]   [อ.พิมพ์พรรณ]    [อ.บุญฤทธิ์]
# 2023-03-24   [อ.พิมพ์พรรณ]      [อ.ปริญญา]    [อ.บริบูรณ์]  [อ.ณัฐฐิกานต์]
# 2023-03-25              []              []              []              []
# 2023-03-26              []              []              []              []
# 2023-03-27      [อ.ปริญญา]   [อ.พิมพ์พรรณ]  [อ.กรองกาญจน์]    [อ.บริบูรณ์]
# 2023-03-28      [อ.ชานนท์]       [อ.กอสิน]      [อ.ปริญญา]       [อ.ธีรพล]
# 2023-03-29         [อ.บวร]      [อ.ภาวิตา]      [อ.ชานนท์]       [อ.ธีรพล]
# 2023-03-30      [อ.ภาวิตา]         [อ.บวร]  [อ.ณัฐฐิกานต์]      [อ.ชานนท์]
# 2023-03-31   [อ.พิมพ์พรรณ]    [อ.บริบูรณ์]      [อ.ปริญญา]  [อ.ณัฐฐิกานต์]
#
#                   Morn Con             EMS             AMD
# 2023-03-01              []  [อ.ณัฐฐิกานต์]      [อ.ภาวิตา]
# 2023-03-02       [อ.กอสิน]      [อ.ภาวิตา]    [อ.บุญฤทธิ์]
# 2023-03-03  [อ.กรองกาญจน์]      [อ.ชานนท์]    [อ.บริบูรณ์]
# 2023-03-04              []      [อ.ชานนท์]       [อ.กอสิน]
# 2023-03-05              []      [อ.ปริญญา]      [อ.ชานนท์]
# 2023-03-06              []      [อ.ปริญญา]       [อ.กอสิน]
# 2023-03-07  [อ.ณัฐฐิกานต์]         [อ.บวร]      [อ.ภาวิตา]
# 2023-03-08              []   [อ.พิมพ์พรรณ]  [อ.กรองกาญจน์]
# 2023-03-09      [อ.ภาวิตา]      [อ.ปริญญา]  [อ.กรองกาญจน์]
# 2023-03-10       [อ.กอสิน]      [อ.ชานนท์]         [อ.บวร]
# 2023-03-11              []    [อ.บุญฤทธิ์]       [อ.ธีรพล]
# 2023-03-12              []    [อ.บุญฤทธิ์]      [อ.ปริญญา]
# 2023-03-13  [อ.ณัฐฐิกานต์]      [อ.ปริญญา]      [อ.ภาวิตา]
# 2023-03-14  [อ.กรองกาญจน์]    [อ.บริบูรณ์]  [อ.ณัฐฐิกานต์]
# 2023-03-15              []      [อ.ชานนท์]    [อ.บุญฤทธิ์]
# 2023-03-16    [อ.บริบูรณ์]         [อ.บวร]  [อ.กรองกาญจน์]
# 2023-03-17    [อ.บริบูรณ์]  [อ.กรองกาญจน์]    [อ.บุญฤทธิ์]
# 2023-03-18              []       [อ.กอสิน]    [อ.บริบูรณ์]
# 2023-03-19              []      [อ.ปริญญา]    [อ.บุญฤทธิ์]
# 2023-03-20       [อ.กอสิน]      [อ.ภาวิตา]      [อ.ปริญญา]
# 2023-03-21  [อ.ณัฐฐิกานต์]       [อ.กอสิน]   [อ.พิมพ์พรรณ]
# 2023-03-22              []    [อ.บริบูรณ์]  [อ.ณัฐฐิกานต์]
# 2023-03-23  [อ.กรองกาญจน์]  [อ.ณัฐฐิกานต์]       [อ.กอสิน]
# 2023-03-24  [อ.กรองกาญจน์]      [อ.ภาวิตา]         [อ.บวร]
# 2023-03-25              []    [อ.บุญฤทธิ์]      [อ.ปริญญา]
# 2023-03-26              []    [อ.บุญฤทธิ์]       [อ.กอสิน]
# 2023-03-27       [อ.กอสิน]         [อ.บวร]  [อ.ณัฐฐิกานต์]
# 2023-03-28      [อ.ภาวิตา]    [อ.บริบูรณ์]  [อ.กรองกาญจน์]
# 2023-03-29              []    [อ.บุญฤทธิ์]       [อ.กอสิน]
# 2023-03-30    [อ.บุญฤทธิ์]    [อ.บริบูรณ์]  [อ.กรองกาญจน์]
# 2023-03-31      [อ.ภาวิตา]       [อ.ธีรพล]  [อ.กรองกาญจน์]
# CpSolverResponse summary:
# status: OPTIMAL
# objective: 0
# best_bound: 0
# booleans: 2025
# conflicts: 1570
# branches: 13929
# propagations: 56321
# integer_propagations: 0
# restarts: 4054
# lp_iterations: 0
# walltime: 0.190622
# usertime: 0.190622
# deterministic_time: 0.055553
# gap_integral: 0
# solution_fingerprint: 0xfed79cd7e2fc9357
