# %%
from datetime import datetime
from ortools.sat.python import cp_model
import pandas as pd
import numpy as np

from datetime import datetime
import os.path
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

import logging

# %%
logging.basicConfig(level=logging.INFO,
                    filename='logs.log',
                    filemode='a',
                    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)

logger = logging.getLogger(__name__)

logger.info('Started')
# Out:
# INFO:__main__:Started

# %%
logging.basicConfig(level=logging.INFO,
                    filename='logs.log',
                    filemode='a',
                    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)

logger = logging.getLogger(__name__)

logger.info('Started')
# Out:
# INFO:__main__:Started

# %%
schedule = Schedule(
    title="Test",
    start=datetime(2021, 1, 1),
    end=datetime(2021, 12, 31),
)

# Create a list of tasks
tasks = [
    Task(title = "Task 1", start=datetime(2021, 1, 1), end=datetime(2021, 1, 10)),
    ]

# Add the tasks to the schedule
for task in tasks:
    schedule.add_task(task)

schedule.list_tasks()
# Out:
# [Task 1 starts at 2021-01-01 00:00:00 and ends at 2021-01-10 00:00:00]

# %%
from datetime import datetime
import os.path
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ["https://www.googleapis.com/auth/calendar.readonly"]

def main():
  """Shows basic usage of the Google Calendar API.
  Prints the start and name of the next 10 events on the user's calendar.
  """
  creds = None
  # The file token.json stores the user's access and refresh tokens, and is
  # created automatically when the authorization flow completes for the first
  # time.
  if os.path.exists("token.json"):
    creds = Credentials.from_authorized_user_file("token.json", SCOPES)
  # If there are no (valid) credentials available, let the user log in.
  if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
      creds.refresh(Request())
    else:
      flow = InstalledAppFlow.from_client_secrets_file(
          "credentials.json", SCOPES
      )
      creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open("token.json", "w") as token:
      token.write(creds.to_json())

  try:
    service = build("calendar", "v3", credentials=creds)

    # Call the Calendar API
    now = datetime.utcnow().isoformat() + "Z"  # 'Z' indicates UTC time
    print("Getting the upcoming 10 events")
    events_result = (
        service.events()
        .list(
            calendarId="em.cmu.teacher@gmail.com",
            timeMin=now,
            maxResults=10,
            singleEvents=True,
            orderBy="startTime",
        )
        .execute()
    )
    events = events_result.get("items", [])

    if not events:
      print("No upcoming events found.")
      return

    # Prints the start and name of the next 10 events
    for event in events:
      start = event["start"].get("dateTime", event["start"].get("date"))
      print(start, event["summary"])

  except HttpError as error:
    print(f"An error occurred: {error}")


if __name__ == "__main__":
  main()
# Out:
# Getting the upcoming 10 events
# 2024-03-06 งด (KL+KL)- BC- BK- 0 : PT ,BC [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-06 KB เรียน AI
# 2024-03-06 -, CC(AMD, AVD)
# 2024-03-06 BK(SMC)
# 2024-03-06T13:00:00+07:00 KS SS Ultrasound ปี 5
# 2024-03-06T13:00:00+07:00 เมย์ หวาน อบรมการใช้งาน Mango Canvas เบื้องต้น
# 2024-03-06T13:00:00+07:00 BK NM อบรม mango canva
# 2024-03-06T13:00:00+07:00 PU สอน ENP
# 2024-03-06T13:30:00+07:00 PT ตรวจรับชุดตู้ปฏิบัติการการแพทย์ฉุกเฉิน
# 2024-03-06T16:30:00+07:00 BW tutorial Sepsis

# %%
calendarApp = CalendarApp()

calendarApp.authenticate()

calendarApp.authenticated

events = calendarApp.read(calendarId= 'em.cmu.teacher@gmail.com',
                 start = datetime(2024, 3, 1),
                    end = datetime(2024, 3, 31))

calendarApp.convert_google_event(events[0])
# Out:
# 2024-03-01 KS KB Elective Ultrasound  กลุ่มที่ 2
# 2024-03-01 PT (BC+BC)- UT- KL- 0 : BK ,BW [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-01 KB สอบลงกองปี 5 (จ2)
# 2024-03-01 -, PU(AMD, AVD)
# 2024-03-01 UT(SMC)
# 2024-03-01T08:00:00+07:00 NM BK SS สอน ventilator workshop ENP
# 2024-03-01T10:00:00+07:00 BW CC PU : Research Day
# 2024-03-01T12:30:00+07:00 ฟ้า เรียน BLS ช่วงบ่าย
# 2024-03-01T13:00:00+07:00 PT KB คุมสอบ OSCE ปี 5
# 2024-03-01T13:00:00+07:00 UT BLS บ่าย
# 2024-03-01T15:00:00+07:00 Bw orientation อาจารย์คุมวิจัย
# 2024-03-02 BC, KB(AMD, AVD)
# 2024-03-02 PU UT not available
# 2024-03-02 BW OD งานพัฒนาคุณภาพ
# 2024-03-02T08:00:00+07:00 BC สอน ENP หัวข้อระบบการจัดการในห้องฉุกเฉิน
# 2024-03-03 BK, SS(AMD, AVD)
# 2024-03-04 -, NM(AMD, AVD)
# 2024-03-04 R3 หนุงหนิง กิ๊บกั๊บ(ช) สตังค์(บ): นำเสนอวิจัยเป็นภาษาอังกฤษ
# 2024-03-04 PT เปิดกองปี 5 (จ1) กลุ่มสุดท้าย
# 2024-03-04 CC (KB+KB)- BK- BW- 0 : PT ,BC [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-04 SS(SMC)
# 2024-03-04T08:00:00+07:00 UT สอน ม พะเยา
# 2024-03-04T09:00:00+07:00 BW สอน CPR พยาบาล critcare
# 2024-03-04T09:00:00+07:00 BC ร่วมเป็นกรรมการนำเสนองานวิจัยแพทย์ประจำบ้าน
# 2024-03-04T09:00:00+07:00 BK weekly meeting SMC
# 2024-03-04T09:30:00+07:00 PU สอน ENP
# 2024-03-04T13:00:00+07:00 BW สอน Basic Resuscitation / Basic Monitoring
# 2024-03-04T13:00:00+07:00 BC สอน  ENP หัวข้อ  clinical concept and nursing management and common medical emergency
# 2024-03-04T16:30:00+07:00 BW tutorial: Onco
# 2024-03-05 งด (BK+BK)- PU- NM- 0 : PT ,BC [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-05 -, UT(AMD, AVD)
# 2024-03-05 SS(SMC)
# 2024-03-05 R3 หญิง(บ): นำเสนอวิจัยเป็นภาษาอังกฤษ
# 2024-03-08 SS (PU+PU)- BK - SS - BC : PT ,BC [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-08 KS KB Elective Ultrasound กลุ่มที่ 2
# 2024-03-08 -, BC(AMD, AVD)
# 2024-03-08 UT(SMC)
# 2024-03-08T08:00:00+07:00 BW  สอน BLS นศพ. ปี 3
# 2024-03-08T10:00:00+07:00 BK สอน ER Learning
# 2024-03-08T10:00:00+07:00 BC NM KL : Research Day
# 2024-03-08T10:00:00+07:00 UT สอน ENP
# 2024-03-08T13:00:00+07:00 KB สอน ACLS ปี 5 (ชั้น 9 ราชนครินทร์)
# 2024-03-08T13:00:00+07:00 PT สอน BLS นศพ. ปี 3
# 2024-03-08T13:00:00+07:00 UT not available บ่าย
# 2024-03-08T13:00:00+07:00 SS สอน ENP
# 2024-03-08T15:00:00+07:00 KL:ปิดกอง Ext.
# 2024-03-08T16:30:00+07:00 BW tutorial OHCA
# 2024-03-09 -, BK(AMD, AVD)
# 2024-03-09 NM KL PU not available
# 2024-03-09 KL CMU Internal Medicine Board Review 2024
# 2024-03-10 -, SS(AMD, AVD)
# 2024-03-11 ฝน ลาพักร้อน
# 2024-03-11 BC (PT+PT)- BW- BC- 0 : UT ,KB [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-11 -, BW(AMD, AVD)
# 2024-03-11 KB: เปิดกองปี 6+1 (แทน SS)
# 2024-03-11 UT(SMC)
# 2024-03-11 Ext ธนภรณ์ มาวน 11-30 มีค 67
# 2024-03-11 BK SS PU BDMS
# 2024-03-11T09:00:00+07:00 BK weekly meeting SMC
# 2024-03-11T10:00:00+07:00 KS สอน Chest Pain Approach
# 2024-03-11T13:00:00+07:00 KL สอน Toxicology + ATLS Review
# 2024-03-11T13:00:00+07:00 KS คุย Viewpoint กับ GE IT
# 2024-03-12 -, KS(AMD, AVD)
# 2024-03-12 BW (KL+KL)- PT- KS- 0 : UT ,KB [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-12 UT(SMC)
# 2024-03-12T09:00:00+07:00 ประชุม service
# 2024-03-12T09:45:00+07:00 ประชุมภาควิชา BC BW PT KS NM
# 2024-03-12T13:00:00+07:00 BC NM : Resident Conference
# 2024-03-12T13:00:00+07:00 CC สอน Acute dyspnea+ Syncope
# 2024-03-12T15:00:00+07:00 BW ประชุมงานคุณภาพโรงพยาบาลฯ
# 2024-03-13 -, KL(AMD, AVD)
# 2024-03-13 PT (NM+NM)- PT- KL- 0 : UT ,KB [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-13 UT(SMC)
# 2024-03-13 KB เรียน AI
# 2024-03-13T08:00:00+07:00 KS สอน ENP cardio2
# 2024-03-13T09:00:00+07:00 ฺBW /Fon ประชุมชั้น 9 ราชฯ
# 2024-03-13T10:00:00+07:00 PT สอน Simulation Disaster
# 2024-03-13T10:00:00+07:00 CC สอนpharmaco ENP
# 2024-03-13T13:00:00+07:00 BC สอน GI Emergency
# 2024-03-19T08:00:00+07:00 BC ร่วมตรวจประเมินหน่วย   ALS โรงพยาบาลแม่ออน สารภี
# 2024-03-19T09:00:00+07:00 BW ประชุม The People Forum
# 2024-03-19T09:00:00+07:00 ประชุม service
# 2024-03-19T10:00:00+07:00 SS สอน ER Learning
# 2024-03-19T12:00:00+07:00 SS CC : Resident Conference
# 2024-03-19T12:00:00+07:00 ER team (MM)
# 2024-03-19T15:00:00+07:00 BW ประชุมงานคุณภาพโรงพยาบาลฯ
# 2024-03-20 BC Director ACLS
# 2024-03-20 BC, PU(AMD, AVD)
# 2024-03-20 KL (UT+UT)- KL- CC- BW : SS ,CC [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-20 KB เรียน AI
# 2024-03-20 BK NM สอน ACLS CMU
# 2024-03-20 SS(SMC)
# 2024-03-20T10:00:00+07:00 ประชุมซ้อมแผนอุบัติเหตุหมู่ทุกหน่วยงานเพื่อปรับแผน
# 2024-03-20T13:00:00+07:00 PT tutorial ปี 5 โดย อาจารย์ประจำกลุ่ม
# 2024-03-21 PU (KS+KS)- SS- CC- 0 : SS ,CC [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-21 KL, PT(AMD, AVD)
# 2024-03-21 CC BW ประชุม Fa KM
# 2024-03-21 UT(SMC)
# 2024-03-21 KB สอน ACLS CMU
# 2024-03-21T08:15:00+07:00 PU CC : Resident Conference
# 2024-03-21T13:00:00+07:00 PU : Toxicology interdepartment conference
# 2024-03-21T13:00:00+07:00 BW ประชุมคณะฯ (801)
# 2024-03-21T13:00:00+07:00 SS: Formative & Innovation Ext
# 2024-03-22 KS KB Elective Ultrasound กลุ่มที่ 2
# 2024-03-22 UT (SS+SS)- KL- UT- 0 : SS ,CC [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-22 UT, KL(AMD, AVD)
# 2024-03-22 BK(SMC)
# 2024-03-22 BW ประชุม TRC
# 2024-03-22 วันสุดท้ายการศึกษา ปี 5
# 2024-03-22T08:00:00+07:00 PT สอบลงกองปี 5 (จ1)
# 2024-03-22T10:00:00+07:00 BC NM : Research Day
# 2024-03-22T13:00:00+07:00 BC คุมสอบ OSCE ปี 5
# 2024-03-22T16:30:00+07:00 PU ติวresus+procedure dent
# 2024-03-23 -, UT(AMD, AVD)
# 2024-03-24 -, BC(AMD, AVD)
# 2024-03-24T00:00:00+07:00 ALL คุมสอบ OSCE ENP
# 2024-03-25 KB (BC+BK)- BW- UT- 0 : BC ,PT [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-25 UT, KB(AMD, AVD)
# 2024-03-25 SS PU BDMS
# 2024-03-25 BK(SMC)
# 2024-03-25T08:00:00+07:00 KL Undergrad ซ่อม OSCE ปี 5
# 2024-03-25T09:00:00+07:00 BC ประชุม อฝส วฉ
# 2024-03-25T09:00:00+07:00 BK weekly meeting SMC
# 2024-03-25T13:00:00+07:00 KS CC สอบซ่อมปี 5 pace OSCE ชั้น 9 ราช
# 2024-03-25T14:00:00+07:00 BW BC PT สัมภาษณ์ อาจารย์ AI
# 2024-03-25T15:00:00+07:00 PT ประชุม สฉนท.
# 2024-03-26 KS (CC+CC)- UT- PU- 0 : BC ,PT [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-26 BK, NM(AMD, AVD)
# 2024-03-26 BC ร่วมซ้อมแผนอุบัติภัยหมู่ โรงพยาบาลหางดง
# 2024-03-26 BK(SMC)
# 2024-03-26T09:00:00+07:00 ประชุม service
# 2024-03-26T10:00:00+07:00 Clincal lead team
# 2024-03-26T12:00:00+07:00 Interdepartment conference
# 2024-03-26T13:00:00+07:00 NM BK UT KB KL BW : Resident Conference
# 2024-03-26T15:00:00+07:00 BW ประชุมงานคุณภาพโรงพยาบาลฯ
# 2024-03-27 PU (UT+BK)- PU- PT- KS : BC ,PT [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-27 PT, CC(AMD, AVD)
# 2024-03-27 KB เรียน AI
# 2024-03-27 SS(SMC)
# 2024-03-27 BK NM SS EMD workshop
# 2024-03-27T13:00:00+07:00 UT,พ.ศรัณปกรณ์: SES Ext
# 2024-03-27T13:00:00+07:00 KL ติว ศรว ปี 5 zoom
# 2024-03-28 BW Director ACLS
# 2024-03-28 CC, PT(AMD, AVD)
# 2024-03-28 NM (PT+UT)- NM- KB- KS : BC ,PT [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-28 SS(SMC)
# 2024-03-28T08:45:00+07:00 KB BC BW UT : Resident Conference
# 2024-03-28T10:00:00+07:00 KS PU CC KL มายด์ หวาน ประชุมทีม undergrad ประจำไตรมาส ตัดเกรดปี 5
# 2024-03-28T13:00:00+07:00 ALL ตัดเกรดปี5 KS PU CC KL BW KB + (BC PT NM)
# 2024-03-29 NM, BW(AMD, AVD)
# 2024-03-29 BK (PU+PU)- BK- NM- BC : BC ,PT [MC(S1,S2) - Supp - Teach - Spe : EMS,Observe]
# 2024-03-29 SS(SMC)
# 2024-03-29T08:00:00+07:00 KL workshop labor ENP
# 2024-03-29T09:00:00+07:00 ซ้อมแผนผู้ป่วยรุนแรง
# 2024-03-29T10:00:00+07:00 KS CC KB : Research Day
# 2024-03-29T13:00:00+07:00 BW UT - ENP: Effective emergency activating system
# 2024-03-30 PT, PU(AMD, AVD)
# 2024-03-30 KS สอน LLL
# 2024-03-30 UT not available
# 2024-03-30T07:45:00+07:00 BW เปิดหลักสูตร Renew EMR
# 2024-03-31 KB, BC(AMD, AVD)
# 2024-03-31 PU not available
# KS KB Elective Ultrasound  กลุ่มที่ 2 starts at 2024-03-01 and ends at 2024-03-02

# %%
calendarApp.convert_google_event(events[0])
# Out:
# KS KB Elective Ultrasound  กลุ่มที่ 2 starts at 2024-03-01 and ends at 2024-03-02

# %%
sheetApp = GoogleSheetApp()

sheetApp.authenticate()
# Out:
# Error authenticating user: ('invalid_scope: Bad Request', {'error': 'invalid_scope', 'error_description': 'Bad Request'})
